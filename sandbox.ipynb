# %%
from Evolution_model import *
import pandas as pd
import seaborn as sns

# %% [markdown]
# Generate Circle dataset

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

n_samples = 400

samples, labels = make_circles(n_samples= n_samples, factor=.7, noise=.06) # Red is scaled by 0.7 of Blue

# %%
df = pd.DataFrame(data=np.column_stack([samples,labels]), columns = ['X1','X2','Y'])
df = df.astype({"Y":'category'})
df.to_csv('Dataset/two_circle.csv',index=False)

# %%
sns.scatterplot(data=df,x='X1',y='X2',hue='Y')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>

# %%
hyperparam = {"L" : 5,
              "n_unit" : [2,8,6,4,2,1],
              "lr" : 1e-5,
              "forward_activation_function" : 'ReLU',
              "backward_activation_function" : 'ReLU',
              "keep_prob_sequence" : [1,0.5,0.6,0.7,1,1]}   #Dropout => No dropout = None OR [1,1,1,1,1,1]

X = df[['X1','X2']]
Y = df[['Y']]


# In[ ]:





# In[147]:


model = Binary_Deep_L_Layer(hyperparam)
model.compiles(initialization='He')
model.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2520/3189343106.py in <module>
#      21 model = Binary_Deep_L_Layer(hyperparam)
#      22 model.compiles(initialization='He')
# ---> 23 model.fit(X,Y)
#
# ~\Desktop\AndrewNG_project\Evolution_model.py in fit(self, X, Y, Epochs, verbose, new_fit)
#     515
#     516         for epoch in range(self.Epochs):
# --> 517             A, cache = L_model_forward(
#     518                 self.X, self.param, activation_function=self.forward_activation_function
#     519             )
#
# ~\Desktop\AndrewNG_project\Evolution_model.py in L_model_forward(X, param, activation_function)
#     279     for l in range(L):  # l = 0,1,2,..,L-1
#     280         A_prev = A
# --> 281         W = param["W" + str(l + 1)]
#     282         b = param["b" + str(l + 1)]
#     283
#
# KeyError: 'W1'

# %%
initiate_param(hyperparam,initialization = 'zero',seed=42)
